# %%
from openai import OpenAI
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
# Out:
# True

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages =[{"role": "user", "content": request}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(model='gpt-5-nano', messages=messages)
print(response.choices[0].message.content)
# Out:
# Design and analyze a hypothetical but realistic scenario requiring cross-domain reasoning (mathematics, computer science, economics, ethics) in which you must propose a policy or system to optimize a complex objective under deep uncertainty. For your answer, provide: 1) a clear objective, constraints, and success metrics; 2) a transparent, parameterized model with explicit assumptions and ranges for key uncertainties; 3) at least two alternative solutions or policies, each with quantitative predictions for welfare, equity, resilience, and cost; 4) a data strategy including collection, validation, handling biases, potential data gaps, and planned robustness checks; 5) an adaptive deployment design that updates as evidence arrives, including trigger conditions and rollback plans; 6) a thorough ethical assessment highlighting potential biases and mitigations; 7) a communication plan tailored to non-experts and diverse stakeholders; 8) a self-critique section that identifies major limitations, epistemic risks, and how you would revise the solution under new information; 9) a concise, evidence-backed recommendation; and 10) a plan to test robustness of the recommendation across plausible alternative assumptions. Do not rely on proprietary data; base your reasoning on publicly credible sources and general knowledge up to 2024.

# %%
import os

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

gemini = OpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
gemini_response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=messages)
print(gemini_response.choices[0].message.content)
# Out:
# A diplomat needs to convey a critical, time-sensitive warning about an imminent military betrayal to an ally over a monitored phone line. The diplomat must use a metaphor based on a childhood game they played together, designed so that the eavesdropper (who has access to their complete biographies but not their subjective memories) hears only nostalgic banter, while the ally immediately understands the warning. Design this metaphor, explain the specific mechanism of the double-meaning, and analyze why an advanced AI eavesdropper would fail to detect the hidden threat despite having perfect historical data on both individuals.
